# %% [markdown]
# ![Screenshot%20%281062%29.png](attachment:Screenshot%20%281062%29.png)

# %% [markdown]
# # DATA SCIENCE AND BUSINESS ANALYTICS

# %% [markdown]
# # TASK 1: Score prediction using supervised machine learning

# %% [markdown]
# # sample data

# %%
# Loading student scores data set
Link='http://bit.ly/w-data'
df=pd.read_csv(Link)
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
# ploting barplot between Hours and Scores
sns.barplot(data=df)
# Out:
# <AxesSubplot:>

# %%
#lets plot a graph with hours on x axis and scores on y axis
plt.figure(figsize=(10,6))
df.plot(x='Hours',y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
#Dividing the data into dependent and independent variables
X=df.iloc[:,0:1]
Y=df.iloc[:,1:]

# %%
X
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8

# %%
Y
# Out:
#     Scores
# 0       21
# 1       47
# 2       27
# 3       75
# 4       30
# 5       20
# 6       88
# 7       60
# 8       81
# 9       25
# 10      85
# 11      62
# 12      41
# 13      42
# 14      17
# 15      95
# 16      30
# 17      24
# 18      67
# 19      69
# 20      30
# 21      54
# 22      35
# 23      76
# 24      86

# %%
#spliting  the data into training and testing models  using test_train_split of scikit learn
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(X, Y, 
                            test_size=0.2, random_state=0)

# %%
X_train
# Out:
#     Hours
# 3     8.5
# 0     2.5
# 21    4.8
# 15    8.9
# 12    4.5

# %%
X_test
# Out:
#     Hours
# 5     1.5
# 2     3.2
# 19    7.4
# 16    2.5
# 11    5.9
# 22    3.8
# 17    1.9
# 24    7.8
# 23    6.9
# 14    1.1
# 1     5.1
# 10    7.7
# 13    3.3
# 8     8.3
# 6     9.2
# 18    6.1
# 4     3.5
# 9     2.7
# 7     5.5
# 20    2.7

# %%
#Training our model
from sklearn.linear_model import LinearRegression  as lr
reg = lr()  
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[9.91065648]])

# %%
plt.figure(figsize=(8,4))
line=reg.coef_*X+reg.intercept_
plt.scatter(X,Y,color='red')
plt.plot(X,line,color='blue')
plt.show()

# %%
# predicting  our model
y_pred=reg.predict(X_test)
print(y_pred)
# Out:
# [[16.88414476]
#  [33.73226078]
#  [75.357018  ]
#  [26.79480124]
#  [60.49103328]
#  [39.67865467]
#  [20.84840735]
#  [79.32128059]
#  [70.40168976]
#  [12.91988217]
#  [52.56250809]
#  [78.33021494]
#  [34.72332643]
#  [84.27660883]
#  [93.19619966]
#  [62.47316457]
#  [36.70545772]
#  [28.77693254]
#  [56.52677068]
#  [28.77693254]]

# %%
#Now lets predict for 9.5 hours 
hours=9.5
score_predict=reg.predict([[hours]])
print("score = {}".format(score_predict))
# Out:
# score = [[96.16939661]]

# %%
# error metrics
# error metrics shows accuracy of our model
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(Y_test, y_pred))
# Out:
# Mean Absolute Error: 4.639699598601577

# %% [markdown]
# #                                             THANK YOU
